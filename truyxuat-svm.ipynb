# %%
# !pip install -q contractions scikit-learn==1.7.2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 63.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 6.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.7.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.2 which is incompatible.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import os
import re
import random
from pathlib import Path
import random
import contractions
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import nltk

from nltk.corpus import stopwords
nltk.download("stopwords")

from nltk.corpus import wordnet
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
label_map = {
    0: "Human Necessities",
    1: "Performing Operations;Transporting",
    2: "Chemistry;Metallurgy",
    3: "Textiles; Paper",
    4: "Fixed Constructions",
    5: "Mechanical Engineering;Lightning;Heating;Weapons;Blasting",
    6: "Physics",
    7: "Electricity",
    8: "General tagging of new or cross-sectional technology"
}

train_path = "/kaggle/input/cs419-dataset/CS419_dataset/train-00000-of-00001.parquet"
val_path   = "/kaggle/input/cs419-dataset/CS419_dataset/validation-00000-of-00001.parquet"
test_path  = "/kaggle/input/cs419-dataset/CS419_dataset/test-00000-of-00001.parquet"

train_df = pd.read_parquet(train_path)
val_df   = pd.read_parquet(val_path)
test_df  = pd.read_parquet(test_path)

print("Train:", train_df.shape)
print("Val:", val_df.shape)
print("Test:", test_df.shape)

# Check columns - we expect at least `text` and `label`
print(train_df.columns.tolist())
# Out:
# Train: (25000, 2)
# Val: (5000, 2)
# Test: (5000, 2)
# ['text', 'label']

# %%
# Light preprocessing (keep sentences intact for tokenizer)
# important_neg = {"not", "no", "never", "cannot", "n't"}
# stop_words = set(stopwords.words("english")) - important_neg

stop_words = set(stopwords.words("english"))

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def light_preprocess(text: str) -> str:
    if not isinstance(text, str):
        text = str(text)

    # # Expand contractions
    # text = contractions.fix(text)

    # lowercase + remove newline
    text = text.lower().strip()
    text = text.replace('\n', ' ')

    # remove URLs & mentions
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"@\w+", "", text)

    # keep only alphabet + number
    text = re.sub(r"[^a-z0-9\s]", " ", text)

    # remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    # stopword removal
    tokens = text.split()
    filtered_tokens = [t for t in tokens if t not in stop_words]

    # stemming
    filtered_tokens = [stemmer.stem(t) for t in filtered_tokens]

    # lemmatize
    # filtered_tokens = [lemmatizer.lemmatize(t) for t in filtered_tokens]

    return " ".join(filtered_tokens)

train_df["clean_text"] = train_df["text"].astype(str).apply(light_preprocess)
val_df["clean_text"]   = val_df["text"].astype(str).apply(light_preprocess)
test_df["clean_text"]  = test_df["text"].astype(str).apply(light_preprocess)

assert "label" in train_df.columns, "train_df must contain a 'label' column"

unique_labels = sorted(train_df["label"].unique())
print("Unique train labels:", unique_labels)
# Out:
# Unique train labels: [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
# 1. Chuẩn bị dữ liệu đầu vào
X_train = train_df["clean_text"]
y_train = train_df["label"]

X_val = val_df["clean_text"]
y_val = val_df["label"]

X_test = test_df["clean_text"]
y_test = test_df["label"]

# %%
# 2. Xây dựng Pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(
        sublinear_tf=True,
        norm="l2"
    )),
    ('clf', LinearSVC(
        penalty ='l2',
        class_weight ='balanced',
        dual='auto',           
        random_state=168,
        loss='squared_hinge',
        max_iter=8000
    ))
])

# %%
# 3. Thiết lập GridSearch
param_grid = {
    'tfidf__max_features': [100_000, 200_000, 300_000], 
    'tfidf__max_df': [0.8, 0.9],
    'tfidf__min_df': [5, 10],
    'tfidf__ngram_range': [(1, 1), (1, 2)], 
    'clf__C': [0.5, 1, 1.5, 2],
}

grid_search = GridSearchCV(
    pipeline,
    param_grid,
    cv=3,            # Cross-validation 3-fold 
    scoring='f1_weighted', # Tối ưu hóa theo F1-score (tốt cho đa lớp)
    n_jobs=-1,       # Sử dụng tất cả các lõi CPU
    verbose=2,
    # error_score="raise"
)

# %%
# 4. Train
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.1s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  33.7s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  34.7s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.0s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  33.2s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.9s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.8s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.2min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.1min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.9s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  33.9s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  39.9s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.6s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.8s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.2s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.0s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  42.0s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  40.6s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  38.6s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  38.6s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  39.2s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 3.1min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  38.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  45.4s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  37.8s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.4s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.4s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  40.3s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  41.1s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  38.2s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  47.3s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.7s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  34.5s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  42.1s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  38.2s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  33.7s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  42.5s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.7min[CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  34.9s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  32.2s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.1s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  33.7s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  32.6s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.9s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.5s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.5s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  39.9s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.3s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.8s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  41.0s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.7min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.6s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  34.3s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  39.8s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  39.1s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.6s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.1s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.8s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  39.0s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  44.7s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  39.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.1s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  44.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  39.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.3s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  43.4s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.7min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  40.4s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  37.2s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  45.2s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 3.0min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.1s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.2s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  42.3s[CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.4s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.8s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.9s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.2s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.3s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  32.5s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  40.7s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.8s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.6s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  38.4s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.2min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.6s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  30.6s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.0s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.4s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  33.3s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  40.0s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.1min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.8s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  32.6s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  38.6s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.4s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  44.1s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.3s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  41.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  38.3s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  38.9s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  41.0s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 3.0min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  38.3s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.0s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  45.6s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=2, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  40.6s[CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.7s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  34.6s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  33.5s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  31.7s
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.2min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=0.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  31.3s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  34.6s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  35.4s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.3min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  32.5s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  30.8s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  38.1s
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=0.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.7s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.5s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  39.8s
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  36.6s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  33.1s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  37.3s
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.2min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.6min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.4min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.6s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.4s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  37.9s
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.7min
# [CV] END clf__C=1.5, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  37.1s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.2s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  38.0s
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.7min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=200000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.7min
# [CV] END clf__C=1.5, tfidf__max_df=0.9, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  37.1s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  36.9s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  46.6s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.7min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.5min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=200000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.8min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  35.0s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  34.9s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=  38.3s
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=2, tfidf__max_df=0.8, tfidf__max_features=300000, tfidf__min_df=10, tfidf__ngram_range=(1, 2); total time= 2.9min
# [CV] END clf__C=2, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  40.8s
# [CV] END clf__C=2, tfidf__max_df=0.9, tfidf__max_features=100000, tfidf__min_df=10, tfidf__ngram_range=(1, 1); total time=  37.5s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(sublinear_tf=True)),
#                                        ('clf',
#                                         LinearSVC(class_weight='balanced',
#                                                   max_iter=8000,
#                                                   random_state=168))]),
#              n_jobs=-1,
#              param_grid={'clf__C': [0.5, 1, 1.5, 2],
#                          'tfidf__max_df': [0.8, 0.9],
#                          'tfidf__max_features': [100000, 200000, 300000],
#                          'tfidf__min_df': [5, 10],
#                          'tfidf__ngram_range': [(1, 1), (1, 2)]},
#              scoring='f1_weighted', verbose=2)

# %%
# 5. Kết quả tốt nhất
print("Best Params:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)

# 6. Đánh giá trên tập Validation và Test
best_model = grid_search.best_estimator_

joblib.dump(best_model, "patent_svc_tfidf.pkl")
print("Model saved!")

print("\n--- Validation Report ---")
y_val_pred = best_model.predict(X_val)
print(classification_report(y_val, y_val_pred, target_names=list(label_map.values())))
# Out:
# Best Params: {'clf__C': 1.5, 'tfidf__max_df': 0.8, 'tfidf__max_features': 300000, 'tfidf__min_df': 5, 'tfidf__ngram_range': (1, 2)}
# Best CV Score: 0.6282609415628778
# Model saved!
#
# --- Validation Report ---
#                                                            precision    recall  f1-score   support
#
#                                         Human Necessities       0.70      0.74      0.72       703
#                        Performing Operations;Transporting       0.57      0.63      0.60       705
#                                      Chemistry;Metallurgy       0.63      0.77      0.70       421
#                                           Textiles; Paper       0.71      0.38      0.49        40
#                                       Fixed Constructions       0.66      0.50      0.57       146
# Mechanical Engineering;Lightning;Heating;Weapons;Blasting       0.55      0.61      0.58       347
#                                                   Physics       0.70      0.74      0.72      1092
#                                               Electricity       0.71      0.75      0.73      1049
#      General tagging of new or cross-sectional technology       0.27      0.10      0.15       497
#
#                                                  accuracy                           0.65      5000
#                                                 macro avg       0.61      0.58      0.58      5000
#                                              weighted avg       0.62      0.65      0.63      5000

# %%
print("\nTest Report")
y_test_pred = best_model.predict(X_test)
print(classification_report(y_test, y_test_pred, target_names=list(label_map.values())))
# Out:
# Test Report
#                                                            precision    recall  f1-score   support
#
#                                         Human Necessities       0.70      0.73      0.71       754
#                        Performing Operations;Transporting       0.55      0.60      0.57       649
#                                      Chemistry;Metallurgy       0.61      0.79      0.69       394
#                                           Textiles; Paper       0.90      0.41      0.56        44
#                                       Fixed Constructions       0.59      0.51      0.55       156
# Mechanical Engineering;Lightning;Heating;Weapons;Blasting       0.51      0.56      0.54       358
#                                                   Physics       0.71      0.74      0.72      1107
#                                               Electricity       0.72      0.79      0.76      1035
#      General tagging of new or cross-sectional technology       0.28      0.10      0.15       503
#
#                                                  accuracy                           0.65      5000
#                                                 macro avg       0.62      0.58      0.58      5000
#                                              weighted avg       0.62      0.65      0.63      5000

# %%
cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=label_map.values(),
    yticklabels=label_map.values()
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Test Set")
plt.tight_layout()
plt.show()

# %%
test_results = test_df.copy()
test_results["y_true"] = y_test.values
test_results["y_pred"] = y_test_pred
test_results["correct"] = test_results["y_true"] == test_results["y_pred"]

# %%
def sample_per_class(df, k=2, seed=168):
    return (
        df.groupby("y_true", group_keys=False)
          .apply(lambda x: x.sample(min(len(x), k), random_state=seed))
    )

print("\nCORRECT (per class)")
correct_samples = sample_per_class(
    test_results[test_results["correct"]], k=3
)

print("\nWRONG (per class)")
wrong_samples = sample_per_class(
    test_results[~test_results["correct"]], k=3
)

def print_samples(df, title):
    print(f"\n=== {title} ===")
    for _, row in df.iterrows():
        print("-" * 80)
        print("True:", label_map[row["y_true"]])
        print("Pred:", label_map[row["y_pred"]])
        print("Text:", row["text"][:500])

print_samples(correct_samples, "CORRECT SAMPLES")
print_samples(wrong_samples, "WRONG SAMPLES")
# Out:
# CORRECT (per class)
#
# WRONG (per class)
#
# === CORRECT SAMPLES ===
# --------------------------------------------------------------------------------
# True: Human Necessities
# Pred: Human Necessities
# Text: this invention is based on a theory of presbyopia different from the classical theory of helmholtz . although the scope of the invention is not to be bound or limited by the inventor &# 39 ; s theory , it is the inventor &# 39 ; s view that the presbyopic loss of accommodation is due to decreased working distance of the ciliary muscle . this theory is described in more detail in u . s . pat . no . 5 , 354 , 331 , referenced above and incorporated herein by reference . consequently , according to
# --------------------------------------------------------------------------------
# True: Human Necessities
# Pred: Human Necessities
# Text: the present inventors have confirmed that tranilast significantly suppressed proliferation of pterygium tissues in the in vitro test for inhibition of cell proliferation using pterygium tissue - derived cells . as a consequence , tranilast has been found to have a highly significant inhibitory effect on the proliferation of pterygium tissue - derived cells and is an extremely useful compound as an agent for inhibiting the progress of pterygium and postoperative recurrence of the same . pharmaceu
# --------------------------------------------------------------------------------
# True: Human Necessities
# Pred: Human Necessities
# Text: the cannula system of this invention is in the form of a kit which , in one embodiment , includes a docking needle 10 with an elongated shaft 11 , shown in fig4 having an insertion point 12 for penetration through the cutaneous layer of a patient . the point 12 passes through the skin , muscle and the hard shell of a bone into the softer cancellous bone material . the point 12 forms a tapered end portion with the base of the taper 13 smoothly merging into the shaft 11 . the shaft may have a cent
# --------------------------------------------------------------------------------
# True: Performing Operations;Transporting
# Pred: Performing Operations;Transporting
# Text: fig1 shows a lifting or walking beam assembly or automatic , generally designated 41 , for a forging press . only portions of four ( 4 ) posts 40 of the press itself appear in the drawing with the press ram being left out for clarity and simplicity . the walking beam assembly 41 disposed between posts 40 comprises two horizontal parallel walking beams hb1 and hb2 . gripping devices 42 adapted to engage workpieces ( not shown ) are secured to those sides of walking beams hb1 and hb2 that face eac
# --------------------------------------------------------------------------------
# True: Performing Operations;Transporting
# Pred: Performing Operations;Transporting
# Text: as shown in fig1 . and 3 , the shear shredder of the present invention , generally designated 10 , includes a support frame 12 , which is mounted above grade on four support legs 14 . the support legs 14 are part of a base frame 16 which supports the frame 12 . the support frame 12 receives removable side walls 18 , 20 and removable end housings 22 , 24 . the side walls 18 , 20 preferably are bolted to the frame 12 , as are the end housings 22 , 24 . the support frame 12 , side walls 18 , 20 and
# --------------------------------------------------------------------------------
# True: Performing Operations;Transporting
# Pred: Performing Operations;Transporting
# Text: an operation of one type of a prior - art turn signal will first be described in order to emphasize benefits achieved by the invention . in brief , in fig3 b , a right - hand turn signal 6 a flashes an amber light on and off while the two white parking or drl lights 4 remain continuously illuminated . this event will be explained step - wise . in fig3 a , the vehicle 3 displays white parking or drl lights 4 , but no turn signal . in fig3 b , the right - hand turn signal 6 a is momentarily illumi
# --------------------------------------------------------------------------------
# True: Chemistry;Metallurgy
# Pred: Chemistry;Metallurgy
# Text: as a typical composition in accordance with the present invention , the waxy substance in the aqueous emulsion thereof may constitute approximately 50 % of the emulsion , and the amount of emulsion employed calculated to be about 0 . 5 %- 20 % of waxy substance , for example wax , to the total amount of water in the water , cement and aggregate mixture . in the following example , except for the control which did not contain any aqueous emulsion of a waxy substance , the aqueous emulsion of waxy
# --------------------------------------------------------------------------------
# True: Chemistry;Metallurgy
# Pred: Chemistry;Metallurgy
# Text: the automatic dishwashing detergent compositions of this invention comprise a ( 1 ) binary system and are ( 2 ) free of chlorine bleach components ; these essential parameters are discussed in detail hereinafter . unless stated to the contrary the &# 34 ; percent &# 34 ; indications stand for percent by weight . the binary active system for use herein is represented by a mixture of an alkoxylated nonionic surface - active agent and a sulfonated aromatic compatibilizing agent . the binary active
# --------------------------------------------------------------------------------
# True: Chemistry;Metallurgy
# Pred: Chemistry;Metallurgy
# Text: as for copper halides which are one of active ingredients of the catalyst , copper chloride , copper bromide and copper iodide are mentioned , and copper chloride may be used usually due to the cost and availability . as for tertiary organophosphorus compounds having phenyl group or alkyl group , alkylarylphosphines like triphenylphosphine , triphenylphosphite and dimethylphenylphosphine , trialkylphosphites like trimethylphosphite and triethylphosphite , and trialkylphosphates like triethylphos
# --------------------------------------------------------------------------------
# True: Textiles; Paper
# Pred: Textiles; Paper
# Text: fig1 is a schematic view of a laundry treating appliance 10 according to an embodiment of the invention . the laundry treating appliance 10 may be any appliance which performs a cycle of operation to clean or otherwise treat items placed therein , non - limiting examples of which include a horizontal or vertical axis clothes washer ; a combination washing machine and dryer ; a tumbling or stationary refreshing / revitalizing machine ; an extractor ; a non - aqueous washing apparatus ; and a revi
# --------------------------------------------------------------------------------
# True: Textiles; Paper
# Pred: Textiles; Paper
# Text: the general term &# 34 ; liquor &# 34 ; or &# 34 ; water &# 34 ;, will be used in the following description to indistinctly mean washing liquor and rinsing water . however , such a simplification will not affect the full and clear understandability of the same description , considering the context in which such terms are used , as anyone skilled in the art will readily appreciate . referring to fig1 which illustrates a preferred embodiment of the present invention , a structure according to the
# --------------------------------------------------------------------------------
# True: Textiles; Paper
# Pred: Textiles; Paper
# Text: meltblowing is a one - step process to make microfiber nonwovens directly from thermoplastic polymers with the aid of high velocity of air to attenuate the melt filaments . it has become an important industrial technique in nonwovens because of its ability to produce fabrics of microfiber structure suitable for filtration media , thermal insulators , battery separators , oil absorbents and many laminate applications . polypropylene ( pp ) is the most widely used polymer for this process . others
# --------------------------------------------------------------------------------
# True: Fixed Constructions
# Pred: Fixed Constructions
# Text: a top sub 10 is connected to a string ( not shown ) that extends from the surface . a bottom sub 12 is connected to more string and perhaps a downhole motor to a mill at the bottom ( all not shown ) as the focus of the present invention is the debris removal tool t that is connected to the string and subs 10 and 12 . a flow tube 14 is sealed at seal 16 to bottom sub 12 and is sealed at seals 18 to top sub 10 . passage 20 that extends through the flow tube 14 allows fluid from the surface to go t
# --------------------------------------------------------------------------------
# True: Fixed Constructions
# Pred: Fixed Constructions
# Text: referring now to fig1 , the basic elements are soil reinforcing mat sm , backing mat bm , stiffening mat st , and top mat tm . these mats are of welded wire construction and typically constructed of w3 . 5 to w12 wire welded together at their intersections and coated with a suitable anti - corrosive coating , such as zinc . mat sm has a face section fs and a floor section ff disposed at right angles relative to one another and comprised of longitudinal wires 10 and intersecting transverse wires
# --------------------------------------------------------------------------------
# True: Fixed Constructions
# Pred: Fixed Constructions
# Text: referring now to fig1 there is shown a drill bit 21 connected to sub 63 extending from shaft 23 of an in - hole motor 25 which in turn is connected to an in - hole force applicator and counter rotation anchor 27 supplied with fluid from conduit bundle 29 . similar apparatus is already known , being disclosed in my u . s . pat . no . 3 , 799 , 277 issued mar . 26 , 1974 , entitled &# 34 ; force applicator ,&# 34 ; to which reference is made for details of the construction thereof . briefly , moto
# --------------------------------------------------------------------------------
# True: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Pred: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Text: referring now to fig1 and 2 , the illustrated exemplary chiller refrigeration system 10 includes a compressor assembly 30 , a condenser 12 , and a cooler or evaporator 20 fluidly coupled to form a circuit . a first conduit 11 extends from adjacent the outlet 22 of the cooler 20 to the inlet 32 of the compressor assembly 30 . the outlet 34 of the compressor assembly 30 is coupled by a conduit 13 to an inlet 14 of the condenser 12 . in one embodiment , the condenser 12 includes a first chamber 17
# --------------------------------------------------------------------------------
# True: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Pred: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Text: referring now specifically to the drawings , the compressor of the present invention is designated by reference numeral 10 and in fig1 is illustrated in association with a conventional pump jack 12 which includes the usual skid or base 14 on which a samson post 16 is supported and which extends upwardly therefrom for supporting a walking beam 18 from a trunnion 20 so that the walking beam 18 can oscillate about a horizontal axis . at one end of the walking beam 18 , a horsehead 22 is attached an
# --------------------------------------------------------------------------------
# True: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Pred: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Text: in the drawings , like reference numbers refer to like objects throughout . objects in the diagrams are not necessarily drawn to scale . fig1 shows a schematic representation of a wind turbine 2 with a first type of prior art cooling arrangement 122 , 3 in the interior of a canopy 24 mounted on a tower 21 . during operation of the wind turbine 2 , rotor blades 22 cause the hub 23 to rotate , so that an electrical machine in the interior of the canopy is caused to generate electricity . heat is g
# --------------------------------------------------------------------------------
# True: Physics
# Pred: Physics
# Text: the present invention relates generally to a method and system for detecting or reviewing defective contacts in the fabrication of semi - conductor devices by using a scanning electron microscope ( sem ). the following description is presented to enable one of ordinary skill in the art to make and use the invention and is provided in the context of a patent application and its requirements . various modifications to the preferred embodiments and the generic principles and features described here
# --------------------------------------------------------------------------------
# True: Physics
# Pred: Physics
# Text: fig4 a - 4d illustrate an exemplary method of operation of a dmd in accordance with the invention . in this example , a memory cell having three sub - cells 54 , 55 , 56 is associated with each mirror cell dm mn , as is illustrated in fig2 for storing three - bit data codes . in practice , the number of bits in each code , and correspondingly the number of memory sub - cells , preferably will be greater , e . g . seven . fig4 a and 4c illustrate the production by different sources of a successio
# --------------------------------------------------------------------------------
# True: Physics
# Pred: Physics
# Text: in the following description , for purposes of explanation , specific numbers , materials and configurations are set forth in order to provide a thorough understanding of the present invention . however , it will be apparent to one skilled in the art that the present invention may be practiced without the specific details . in other instances , well known features are omitted or simplified in order not to obscure the present invention . parts of the description will be presented using terms such
# --------------------------------------------------------------------------------
# True: Electricity
# Pred: Electricity
# Text: please refer to fig1 ˜ 5 , which show a power supply unit that is compatible with different plug types and can be plugged to the power outlet at different directions . the power supply unit may be , but is not limited to , power adaptors , chargers , power converters , or combinations thereof . the power supply unit comprises a main body 1 and a plug 2 . for explanation purposes , the crosswise direction of the main body 1 is defined by the x - axis as a first direction x . the longitudinal dire
# --------------------------------------------------------------------------------
# True: Electricity
# Pred: Electricity
# Text: reference will now be made in detail to the present exemplary embodiments of the invention , examples of which are illustrated in the accompanying drawings . wherever possible , the same reference numbers will be used throughout the drawings to refer to the same or like parts . an exemplary embodiment of the ground fault circuit interrupter ( gfci ) of the present invention is shown in fig1 , and is designated generally throughout by reference numeral 10 . as embodied herein and depicted fig1 ,
# --------------------------------------------------------------------------------
# True: Electricity
# Pred: Electricity
# Text: before describing in detail the particular method of achieving an extended range of original scene exposures over which the image captured on film retains its linear character , it should be observed that the present invention resides primarily in a novel combination of steps to generate and utilize an inverse shaping lut which are readily executed using conventional digital image scanning and processing circuit and components . accordingly , the structure , control , and arrangement of such con
# --------------------------------------------------------------------------------
# True: General tagging of new or cross-sectional technology
# Pred: General tagging of new or cross-sectional technology
# Text: fig1 illustrates a coated substrate 100 according to some embodiments of the present invention . the substrate 102 is glass in some embodiments of the present invention . the substrate 102 may be of a variety of glass types , including soda lime glass , borosilicate glass , or pure silica . in other embodiments , substrate 102 may be silicon . layer 101 is a silane layer . silane layer 101 may be comprised of amino silanes , epoxy silanes , and / or mercapto silanes in some embodiments . silane
# --------------------------------------------------------------------------------
# True: General tagging of new or cross-sectional technology
# Pred: General tagging of new or cross-sectional technology
# Text: fig1 and 2 schematically illustrate a wave soldering apparatus preferably used in practising the inventions set forth herein . basically , the apparatus 10 comprises an inclined conveyor 11 for moving a pallet 12 of elongate frames of electronic packages or other electronic parts to receive a coating of solder . the package or parts , first pass above a first station comprising a flux container 14 which includes top baffles and a pump ( not shown ) to form a fluxing zone 15 above the level of fl
# --------------------------------------------------------------------------------
# True: General tagging of new or cross-sectional technology
# Pred: General tagging of new or cross-sectional technology
# Text: referring to fig1 as described above , the power conversion system 10 of evs , fuel cell vehicles , and hevs typically includes a separate , discrete tim assembly 12 and dc / dc converter assembly 14 . the tim 12 inverts the high - voltage dc bus voltage to an ac voltage suitable for powering the motor 16 , such as a 3 - phase ac voltage . this power is inverted for driving and controlling the motor 16 , i . e ., for generating torque . the motor 16 , in combination with the transaxle , converts
#
# === WRONG SAMPLES ===
# --------------------------------------------------------------------------------
# True: Human Necessities
# Pred: Performing Operations;Transporting
# Text: other objects , features and advantages of the invention will become apparent from a consideration of the following detailed description and the accompanying drawings . referring to fig1 , the invention disclosed in the incorporated material is broadly embodied in a system 10 for use in administrating therapeutic gas to a patient . system 10 comprises a first equalization valve 12 that is fluidically connected to a source 14 of therapeutic gas . a first fluid conduit 16 has an inlet end 18 fluid
# --------------------------------------------------------------------------------
# True: Human Necessities
# Pred: Performing Operations;Transporting
# Text: one embodiment of the chamber is illustrated in fig1 , 2 , 3 , and 4 . fig1 shows said chamber with six sides when unfolded in its linear state . drawing reference numbers 1 , 2 , 3 , 4 , 5 , and 6 show six panels that form the body of said chamber . we contemplate the panels being made of acrylic , however other materials can be used which would be suitable . drawing reference numbers 7 a , 7 b , and 7 c show the smooth side of the edging , using hatch lines through the edging . edging within t
# --------------------------------------------------------------------------------
# True: Human Necessities
# Pred: Chemistry;Metallurgy
# Text: referring to fig1 , an upright extraction cleaner 10 according to the invention comprises an upright handle 12 and a base 14 . a clean solution tank 18 is carried by the upright handle 12 . the base 14 is partially supported by wheels 16 and by suction nozzle 20 . a fluid dispensing nozzle 22 is disposed on an underside of the base 14 to the rear of the suction nozzle 20 for dispensing a cleaning solution on a surface being cleaned . extraction cleaning using exothermic chemical heat according t
# --------------------------------------------------------------------------------
# True: Performing Operations;Transporting
# Pred: Human Necessities
# Text: as shown in fig1 a shipping container 10 is comprised of three basic elements which are assembled to form the improved insulative container of this invention . the outermost component of the insulated container is the paperboard box 11 which is conventional in form and well known in terms of construction to those skilled in the art . located interiorly to and within the box is a plastic bag 12 which forms the vapor barrier of the invention . the plastic bag is also of conventional fabrication ,
# --------------------------------------------------------------------------------
# True: Performing Operations;Transporting
# Pred: Human Necessities
# Text: according to the invention , at least an outer insulating layer of the electrical wire or cable includes at least one anti - contaminating agent , e . g . an anti - microbial or anti - fungal agent dispersed and suspended in the coating of the thermoplastic polymer or matrix . the term “ biologically resistant ” or alternative “ anti - contaminating ” as used herein is intended to include , but is not limited to , anti - microbial agents , anti - fungal agents , anti - viral agents , anti - thro
# --------------------------------------------------------------------------------
# True: Performing Operations;Transporting
# Pred: Electricity
# Text: as discussed earlier , there is need for deep , oxide - filled , trenches that are free of trapped voids . the present invention achieves this by forming the trench - filling oxide by thermal oxidation . this approach has several advantages ( in addition to eliminating void formation ). it makes possible the filling of deeper trenches with oxide . by using thermal oxide ( as compared to the lpcvd oxide that is standard in the prior art ), a less porous oxide of much better quality is obtained .
# --------------------------------------------------------------------------------
# True: Chemistry;Metallurgy
# Pred: Physics
# Text: the various elements identified by numerals in the drawings are listed in the following integer list . referring to fig1 and 2 of the drawings there is shown a septic tank generally designated by the reference numeral 1 which may typically be a reinforced concrete construction . the septic tank includes a circular base 2 and a cylindrical side wall 3 . a lid 5 covers the top of the tank . reinforcement 4 is provided in the base , side wall and lid of the tank . typically this may comprise steel
# --------------------------------------------------------------------------------
# True: Chemistry;Metallurgy
# Pred: Electricity
# Text: referring now to the drawings , wherein like reference numerals designate identical or corresponding parts throughout the several views , and more particularly to fig1 a thereof , is an ozonizer consisting of two parallel , electrically conductive plate - shaped electrodes 2 , 2 &# 39 ; which are separated from each other by a dielectric layer 3 having a uniform thickness , as well as by a discharge gap 4 . the dielectric layer 3 is arranged at the surface of the electrode 2 &# 39 ;, so that the
# --------------------------------------------------------------------------------
# True: Chemistry;Metallurgy
# Pred: Physics
# Text: referring now more particularly to the drawings , a nephelometer 10 is illustrated for testing bacteria samples to determine whether the samples contain a predetermined bacteria count and hence whether the sample is standardized . accordingly , the apparatus is referred to as a standardized inoculum reader . to determine whether the bacteria samples contain the standardized concentration utilizing the standardized inoculum reader 10 shown in fig1 the reader 10 is calibrated using a sample having
# --------------------------------------------------------------------------------
# True: Textiles; Paper
# Pred: Fixed Constructions
# Text: asphalt roofing materials , including shingles , are manufactured by following conventional procedures . bituminous prepared roofing has heretofore been extensively manufactured using as a base a fibrous web such as a sheet of roofing felt or fiberglass mat , impregnating the fibrous web with a bituminous material and coating one or both surfaces of the impregnated web with a weather - resistant bituminous coating material . the bituminous coating material usually contains a mineral filler such
# --------------------------------------------------------------------------------
# True: Textiles; Paper
# Pred: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Text: several embodiments of the present invention will be described . fig1 to 5 b illustrate a first embodiment in accordance with the invention . referring to fig1 , an overall construction of a drum type washer - drier of the first embodiment is shown . the drum type washer - drier includes a base 1 made of a resin . a generally rectangular outer cabinet 2 is mounted on the base 1 . the cabinet 2 includes a front cover 3 having a centrally formed access opening 3 a ( see fig2 ) through which laundr
# --------------------------------------------------------------------------------
# True: Textiles; Paper
# Pred: Human Necessities
# Text: referring now to the drawings , and especially to fig1 and 2 , an electronic pressing iron , generally indicated by numeral 10 and embodying the present invention is shown therein . the electronic pressing iron 10 has a cast aluminum soleplate 12 . a plastic housing 14 , having a right side 14a and a left side 14b and consisting of a phenolic lower housing 16 and a thermoplastic polyester upper housing 18 , is connected to the soleplate 12 . referring now to fig2 and 3 , the phenolic lower housi
# --------------------------------------------------------------------------------
# True: Fixed Constructions
# Pred: Performing Operations;Transporting
# Text: turning first to fig1 we see the improved cuttings injection processing system comprises a newly configured processing module 12 which , when assembled , is self contained and fully operational for operation on an offshore drilling location . in this improved embodiment 1 the module 12 also comprises an in - feed cuttings conveyor 14 or other such transfer means , which feed , overflow drill cuttings from a drilling rig &# 39 ; s drilling fluid mud recovery system &# 39 ; s shell shakers to the
# --------------------------------------------------------------------------------
# True: Fixed Constructions
# Pred: Physics
# Text: with reference now to the drawings in which like numerals represent like elements throughout the several views , a presently preferred embodiment of the present invention is depicted in fig1 . a powered sliding gate 10 with a leading edge 11 is depicted in an intermediate position as it is being moved in the direction of arrow 13 . many different suitable devices which are well known in the art can be employed to drive sliding gate 10 , such as electric , pneumatic , or hydraulic motors . slidin
# --------------------------------------------------------------------------------
# True: Fixed Constructions
# Pred: Performing Operations;Transporting
# Text: reference will now be made to the following detailed description , taken in conjunction with the accompanying drawings , wherein like parts are designated by like numerals . referring now to fig1 , it shows a self - elevating jack - up unit . the jack - up unit is a mobile offshore structure that is used for mineral exploration and production . a typical jack - up unit is provided with a plurality of truss legs 12 , which extend through openings in a floatable hull 14 of the jack - up unit . alt
# --------------------------------------------------------------------------------
# True: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Pred: Electricity
# Text: fig1 shows a schematic view from the side of a seat device 10 according to the invention , which comprises a seat region 30 and a region of a headrest 40 , which is formed at an upper end of the seat device 10 . the seat device 10 comprises a seat frame 50 in the region of its underside , this seat frame being used to connect the seat to an aircraft ( not illustrated ). the seat device 10 comprises an armrest 80 in the region of a transverse end of the seat region 30 , this armrest comprising a
# --------------------------------------------------------------------------------
# True: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Pred: Performing Operations;Transporting
# Text: with reference to fig2 a hydraulic circuit 20 for the backhoe 10 has a pump 22 which forces fluid from a tank 24 into a supply line 26 . a conventional system pressure relief valve 28 opens in the event that the pump pressure exceeds a given safety threshold , thereby relieving that pressurized fluid to the tank 24 via the tank return line 29 . the supply line 26 and tank return line 29 are connected to a plurality of functions on the backhoe tractor 10 . the hydraulic circuit for the boom swing
# --------------------------------------------------------------------------------
# True: Mechanical Engineering;Lightning;Heating;Weapons;Blasting
# Pred: General tagging of new or cross-sectional technology
# Text: having reference now to the drawing , and initially to fig1 , there is illustrated a flow volume limiting device generally designated as 20 and constructed in accordance with the principles of the present invention . the device 20 may be employed in applications where it is desired to limit the measured volume of liquid flow to a maximum value . in fig1 , the device 20 is connected in a water supply system 22 of a water utilizing device or appliance 24 such as a clothes washing machine . in this
# --------------------------------------------------------------------------------
# True: Physics
# Pred: General tagging of new or cross-sectional technology
# Text: the present invention provides a method for fabricating a bottom spin - valve sensor element of high magnetoresistive ratio by forming a novel , specularly reflecting nano - oxide layer within its pinned layer . referring first to fig1 a , there is shown a schematic cross - sectional view of a typical prior art configuration of a bottom spin - filter element stack having a synthetic antiferromagnetically pinned ( syap ) layer . compositionally , said stack has the form : as shown in fig1 a , the
# --------------------------------------------------------------------------------
# True: Physics
# Pred: Human Necessities
# Text: referring now to the present invention in more detail , in fig1 there is shown an adjustable winged eyecup ( 10 ). the winged eyecup ( 10 ) is made up of three basic areas ; first the wing ( 12 ) second the band ( 14 ) and third the fastener ( 16 ). the wing &# 39 ; s ( 12 ) primary purpose is to create a seal to the users eye and block light , and elements such as wind , rain , and snow entering into the eye . the wing must be sufficiently large enough to surround user &# 39 ; s eye . the band
# --------------------------------------------------------------------------------
# True: Physics
# Pred: Performing Operations;Transporting
# Text: although the foregoing description contains many specifics , these should not be construed as limiting the scope of the present invention , but merely as providing illustrations of some exemplary embodiments . similarly , other embodiments of the invention may be devised that do not depart from the spirit or scope of the present invention . features from different embodiments may be employed in combination . the scope of the invention is , therefore , indicated and limited only by the appended c
# --------------------------------------------------------------------------------
# True: Electricity
# Pred: Physics
# Text: the present invention provides for hdcp over usb using a virtualizing usb controller that provides a physical usb controller for external communications and a virtual usb controller for communicating with an incorporating host . when the host inquiries whether hdcp is supported , the virtual usb controller responds that it is supported . when a video data is received from the host , an hdcp module on the virtualizing usb controller encrypts the video . the virtualizing usb controller then transm
# --------------------------------------------------------------------------------
# True: Electricity
# Pred: Physics
# Text: in fig1 , an infrared camera 1 according an embodiment of the invention is shown . the infrared camera 1 comprises three main parts , a lens assembly 10 at one end for capturing radiation and at the other end an assembly 110 which may comprise a plurality of control devices 120 and at least one interface medium 130 . the plurality of control devices 120 could for example be a display , record / push - buttons and thumb - joysticks for programming , parameter settings and menu selection from a di
# --------------------------------------------------------------------------------
# True: Electricity
# Pred: Chemistry;Metallurgy
# Text: a temperature independent resistor can be formed in accordance with this invention by codepositing a deep level dopant and a semiconductive material on a heated substrate to form a polycrystalline film . the film only has crystals of the semiconductive material , and these crystals are supersaturated with the deep level dopant . thus there is only one crystalline phase , and the crystals forming that phase are host crystals for the deep level dopant . by the expression deep level dopant , i mean
# --------------------------------------------------------------------------------
# True: General tagging of new or cross-sectional technology
# Pred: Physics
# Text: to present a uniform memory model to all executing programs , modern operating systems abstract memory addresses used by the system &# 39 ; s virtual memory manager ( vmm ). ( the vmm is a process that is primarily responsible for managing the use of both main memory and virtual memory . to do so , the vmm keeps track of each page of data that is in memory and swaps pages to and from the storage device both on demand and routinely .) this memory abstraction creates a range of available memory ad
# --------------------------------------------------------------------------------
# True: General tagging of new or cross-sectional technology
# Pred: Performing Operations;Transporting
# Text: fig1 shows an apparatus for producing an inventive absorbent structure . the apparatus comprises a funnel - shaped feed mechanism 2 through which a solid matter mixture , which preferably was produced in advance in accordance with the by - weight percentile composition of the individual components , can be fed into a cylindrical interior 4 of a high - pressure stable tubular housing 5 of the production apparatus . a shaft 6 extends in this interior 4 having a helical screw 8 driven by an electri
# --------------------------------------------------------------------------------
# True: General tagging of new or cross-sectional technology
# Pred: Physics
# Text: an overall architecture diagram of the job search system 100 in accordance with an embodiment of this disclosure is shown in fig1 . the system 100 can be thought of as having three sections : an external input section 101 , a data handling section 103 , and an output handling section 105 . basically the data handling section reaches to the external input section 101 for job data , processes the data , organizes and verifies validity of the data , categorizes the job data , and provides the data
# /tmp/ipykernel_13/662025551.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(min(len(x), k), random_state=seed))
# /tmp/ipykernel_13/662025551.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(min(len(x), k), random_state=seed))

# %%
SAMPLES_PER_CLASS = 2

# Tạo dataframe tạm để dễ group
viz_df = train_df[["clean_text", "label"]].copy()

viz_df = (
    viz_df
    .groupby("label", group_keys=False)
    .apply(lambda x: x.sample(
        n=min(len(x), SAMPLES_PER_CLASS),
        random_state=168
    ))
    .reset_index(drop=True)
)

X_viz_text = viz_df["clean_text"]
y_viz = viz_df["label"].values
# Out:
# /tmp/ipykernel_13/674468383.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(

# %%
# Dùng TF-IDF đã train
tfidf = best_model.named_steps["tfidf"]
X_viz_tfidf = tfidf.transform(X_viz_text)

# Giảm chiều
svd = TruncatedSVD(n_components=2, random_state=168)
scaler = StandardScaler()

X_viz_2d = make_pipeline(svd, scaler).fit_transform(X_viz_tfidf)

# %%
svm_2d = LinearSVC(C=1.0, random_state=168)
svm_2d.fit(X_viz_2d, y_viz)
# Out:
# LinearSVC(random_state=168)

# %%
plt.figure(figsize=(10, 8))

# Scatter
scatter = plt.scatter(
    X_viz_2d[:, 0],
    X_viz_2d[:, 1],
    c=y_viz,
    cmap="tab10",
    s=80,
    edgecolors="k",
    alpha=0.9
)

# Lưới
x_min, x_max = X_viz_2d[:, 0].min() - 1, X_viz_2d[:, 0].max() + 1
y_min, y_max = X_viz_2d[:, 1].min() - 1, X_viz_2d[:, 1].max() + 1

xx, yy = np.meshgrid(
    np.linspace(x_min, x_max, 300),
    np.linspace(y_min, y_max, 300)
)

Z = svm_2d.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Decision regions
plt.contourf(
    xx, yy, Z,
    alpha=0.25,
    cmap="tab10"
)

# Legend theo label_map
handles, _ = scatter.legend_elements()
labels = [label_map[i] for i in sorted(np.unique(y_viz))]
plt.legend(handles, labels, title="IPC Section", fontsize=9)

plt.title("SVM Decision Boundary (2D SVD Projection – 10 samples/class)")
plt.xlabel("SVD Component 1")
plt.ylabel("SVD Component 2")
plt.tight_layout()
plt.show()
